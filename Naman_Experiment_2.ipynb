# %% [markdown]
# <a href="https://colab.research.google.com/github/NamanGautam0404/R-L/blob/main/Naman_Experiment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
#np.random.seed(1)
x=np.random.randint(0, 50, 1000)
x
# Out:
# array([41, 20, 37, 27, 17, 31, 15,  3,  9, 21, 48, 14,  7, 30, 30,  5, 14,
#        32, 46, 40, 35,  9, 31, 14,  5, 35, 30, 44, 28, 13, 31, 38, 23, 24,
#        19,  9, 13, 45, 14,  3, 48, 43, 22, 28, 37, 36,  9,  6, 28, 36, 29,
#        47, 35,  4,  4, 20, 32, 46, 10, 28, 36,  9,  1, 48, 46, 18, 29,  0,
#        12, 21, 29, 37, 15, 20, 31, 30, 26, 15,  4, 20, 46, 13, 23,  3, 45,
#        16, 36,  9,  6, 43, 44, 27, 29, 32, 27, 38,  5, 26,  4, 26,  2, 36,
#         6, 10, 46, 43, 15, 36, 34, 33, 26, 48, 10, 24, 39, 30, 31, 20, 49,
#        28, 29, 13, 26, 37, 40, 11, 13, 18,  1, 42,  1, 15, 20, 24, 24,  6,
#        27,  1, 42, 25, 41, 17,  2, 29, 31, 22,  8, 24, 44,  9, 49, 29,  4,
#         1, 27,  3, 47, 44,  1, 34, 34,  7, 48, 28, 15, 40, 26,  9,  3,  4,
#        22, 17, 16, 30, 39, 17, 31, 46,  2,  3, 12,  1, 24, 41, 20, 30, 47,
#        12,  1,  9, 22, 19,  6, 35,  5, 11, 39,  1, 38,  7, 13, 25, 46, 10,
# ...

# %%
y=x=np.random.normal(0,1000,1000)
y
# Out:
# array([-2.46895204e+02, -9.83522069e+02, -1.57060316e+03, -1.35545821e+03,
#         1.24656654e+03,  7.79368583e+02,  3.58271229e+02, -1.56149059e+03,
#        -5.10228258e+02, -1.03903057e+03,  1.34242569e+03,  1.65628022e+03,
#         1.22257321e+03, -6.37953107e+02,  3.66511717e+01,  1.04307484e+02,
#         1.18549057e+03, -1.43056205e+03,  2.23387730e+02,  7.02768886e+02,
#         3.05995056e+03, -4.81522844e+02,  4.98798703e+00, -1.64980743e+03,
#        -1.03614632e+03, -3.90259589e+02, -5.38759662e+02,  5.20218570e+02,
#        -5.79844247e+02,  1.51391950e+03,  2.24500253e+03,  1.25706510e+03,
#        -5.22758891e+02,  9.51960297e+02, -9.79026448e+02, -1.26235653e+03,
#        -9.70733004e+01, -6.90988915e+01,  1.59258337e+02,  1.91520744e+03,
#        -7.48601128e+02,  7.84968552e+02, -1.00574226e+02, -3.77352654e+02,
#        -1.01961035e+03, -6.18890531e+02,  6.05306130e+02, -5.98863605e+02,
# ...

# %%
from ast import increment_lineno
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# positivr correlation with some noice
y = x + np.random.normal(0,10,1000)
# Positive correlation with some noice
y = x + np.random.normal(0,10,1000)

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.99994611],
#        [0.99994611, 1.        ]])

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
z = 100-x

# %%
matplotlib.style.use('ggplot')
plt.scatter(x,z)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd
df = pd.DataFrame({'a': np.random.randint(0,50,1000)})
df['b'] = df['a'] +np.random.normal(0,10,1000) # positivity corerelated with 'a'
df['c'] = 100-df['a'] +np.random.normal(0,5,1000)
df['d'] = np.random.normal(0,50,1000)

# %%
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.825313 -0.945396  0.094039
# b  0.825313  1.000000 -0.778584  0.099517
# c -0.945396 -0.778584  1.000000 -0.092413
# d  0.094039  0.099517 -0.092413  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize = (6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5116\1944245446.py:4: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()
